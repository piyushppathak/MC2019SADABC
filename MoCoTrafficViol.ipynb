# %% [markdown]
# #### Load Libraries

# %%
import pandas as pd #load pandas library
import numpy as np #loads numpy library
import json #load JSON library
import math

import time #load TIME library
from datetime import datetime  #to convert data to datetime that does not fall within the pandas.to_datetime function timeframe

from shapely.geometry import Point  #transform latitude/longitude to geo-coordinate data

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Load Config and Data Locations

# %%
#load config and csv file data with headers
datasrclocation = "datasets/MoCoTrafficViolations.csv"
datadstlocation = "tableau/MoCoTrafficViolations.csv"
configlocation = "config/config.json"

# %% [markdown]
# #### Load Data and peek into data

# %%
#load config and csv file data with headers
df = pd.read_csv(datasrclocation)
df.sample(1)
# Out:
#                                         SeqID Date Of Stop Time Of Stop  \
# 1377908  1aa640ea-8612-4c38-ac00-669593e4c2dc   03/05/2013     12:32:00
#
#         Agency                            SubAgency  \
# 1377908    MCP  Headquarters and Special Operations
#
#                                                Description  \
# 1377908  EXCEEDING MAXIMUM SPEED: 70 MPH IN A POSTED 55...
#
#                    Location   Latitude  Longitude Accident  \
# 1377908  N/B I-270 @ EXIT 5  39.071825 -77.161586       No
#
#                          ...                      Charge  \
# 1377908                  ...                    21-801.1
#
#                         Article Contributed To Accident   Race Gender  \
# 1377908  Transportation Article                   False  WHITE      M
#
#             Driver City Driver State DL State          Arrest Type  \
# 1377908  UPPER MARLBORO           MD       MD  B - Unmarked Patrol
#
#                                    Geolocation
# 1377908  (39.0718254666667, -77.1615857666667)
#
# [1 rows x 36 columns]

# %% [markdown]
# #### Data CleanUp

# %%
df['Violation Type'] = np.where(df['Violation Type'] == 'SERO', 'ESERO', df['Violation Type'])

# %%
df['SubAgency'] = np.where(df['SubAgency'] == 'S15', '3rd District, Silver Spring', df['SubAgency'])

# %%
df['SubAgency'] = np.where(df['SubAgency'] == 'W15', '4th District, Wheaton', df['SubAgency'])

# %%
df.sample(5)
# Out:
#                                         SeqID Date Of Stop Time Of Stop  \
# 58557    b79e9602-515c-48d0-b4ea-15664f43effd   04/11/2019     20:42:00
# 793310   46e2014f-4183-4c0d-847e-b026c4dddafa   11/03/2015     09:31:00
# 1133648  1ccde1d5-1a61-4ede-b3f0-8d8367d22970   05/14/2014     18:45:00
# 384093   811103ef-7b49-4ac4-b974-94cc8df5108e   10/03/2017     20:19:00
# 1417671  ce9fd9b7-0b84-424a-b1d2-8f0bcb5f8d4c   12/05/2012     00:39:00
#
#         Agency                SubAgency  \
# 58557      MCP    4th District, Wheaton
# 793310     MCP    4th District, Wheaton
# 1133648    MCP   2nd District, Bethesda
# 384093     MCP   2nd District, Bethesda
# 1417671    MCP  1st District, Rockville
#
#                                                Description  \
# 58557           DRIVER FAIL TO MAKE REQUIRED STOP AT  SIGN
# 793310   DRIVER FAILURE TO STOP AT STEADY CIRCULAR RED ...
# 1133648                OPERATOR NOT RESTRAINED BY SEATBELT
# 384093   DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC...
# 1417671         EXCEEDING THE POSTED SPEED LIMIT OF 45 MPH
#
#                                          Location   Latitude  Longitude  \
# 58557                 GEORGIA AVE @ MONTPELIER RD  39.095523 -77.079555
# 793310                  GEORGIA AVE AT WINDHAM LN  39.031808 -77.048338
# 1133648        OLD GEORGETOWN RD @ ROCKVILLE PIKE  39.049642 -77.113543
# 384093         OLD GEORGETOWN RD / DEMOCRACY BLVD  39.024577 -77.126390
# 1417671  NB ROUTE 27 BETWEEEN OBSERVATION AND 355  39.211975 -77.248275
#
#         Accident                  ...                         Charge  \
# 58557         No                  ...                      21-202(m)
# 793310       Yes                  ...                     21-202(h1)
# 1133648       No                  ...                    22-412.3(b)
# 384093        No                  ...                     21-201(a1)
# 1417671       No                  ...                       21-801.1
#
#                         Article Contributed To Accident      Race Gender  \
# 58557    Transportation Article                   False     BLACK      M
# 793310   Transportation Article                    True  HISPANIC      M
# 1133648  Transportation Article                   False     WHITE      M
# 384093   Transportation Article                   False     WHITE      M
# 1417671  Transportation Article                   False     BLACK      M
#
#            Driver City Driver State DL State        Arrest Type  \
# 58557        ROCKVILLE           MD       MD  A - Marked Patrol
# 793310   SILVER SPRING           MD       MD  A - Marked Patrol
# 1133648      ROCKVILLE           MD       MD  A - Marked Patrol
# 384093         POTOMAC           MD       MD  A - Marked Patrol
# 1417671   GAITHERSBURG           MD       MD  A - Marked Patrol
#
#                                    Geolocation
# 58557           (39.0955233333333, -77.079555)
# 793310   (39.0318083333333, -77.0483383333333)
# 1133648  (39.0496416666667, -77.1135433333333)
# 384093           (39.0245766666667, -77.12639)
# 1417671       (39.21197475, -77.2482754833333)
#
# [5 rows x 36 columns]

# %% [markdown]
# #### Define Maryland Transportation Code Functions

# %%
def MDTransCode(charge):
    switcher = {
            '1' : 'Title 1 - Definitions; General Provisions',
            '2' : 'Title 2 - Department of Transportation',
            '3' : 'Title 3 - Financing by Department',
            '4' : 'Title 4 - Revenue Facilities',
            '5' : 'Title 5 - Aviation',
            '6' : 'Title 6 - Ports',
            '7' : 'Title 7 - Mass Transit',
            '8' : 'Title 8 - Highways',
            '9' : 'Title 9 - Railroads',
            '10' : 'Title 10 - Transportation Compacts',
            '11' : 'Title 11 - Vehicle Laws -- Definitions; General Provisions',
            '12' : 'Title 12 - Vehicle Laws -- Motor Vehicle Administration',
            '13' : 'Title 13 - Vehicle Laws -- Certificates of  : Title and Registration of Vehicles',
            '14' : 'Title 14 - Vehicle Laws -- Antitheft Laws',
            '15' : 'Title 15 - Vehicle Laws -- Licensing of Businesses and Occupations',
            '16' : 'Title 16 - Vehicle Laws -- Drivers Licenses',
            '17' : 'Title 17 - Vehicle Laws -- Required Security',
            '18' : 'Title 18 - Vehicle Laws -- For-Rent Vehicles',
            '18.5' : 'Title 18.5. Peer-to-Peer Car Sharing Programs.',
            '19' : 'Title 19 - Vehicle Laws -- Civil Liability of Governmental Agencies',
            '20' : 'Title 20 - Vehicle Laws -- Accidents and Accident Reports',
            '21' : 'Title 21 - Vehicle Laws -- Rules of the Road',
            '22' : 'Title 22 - Vehicle Laws -- Equipment of Vehicles',
            '23' : 'Title 23 - Vehicle Laws -- Inspection of Used Vehicles and Warnings for Defective Equipment',
            '24' : 'Title 24 - Vehicle Laws -- Size, Weight, and Load; Highway Preservation',
            '25' : 'Title 25 - Vehicle Laws -- Respective Powers of State and Local Authorities; Disposition of Abandoned Vehicles',
            '26' : 'Title 26 - Vehicle Laws -- Parties and Procedure on Citation, Arrest, Trial, and Appeal',
            '27' : 'Title 27 - Vehicle Laws -- Penalties; Disposition of Fines and Forfeitures'
    }
    return switcher.get(charge,'Unknown')

# %%
def ESERO(charge):
    switcher = {
            '50' : 'Brakes',
            '51' : 'Tires',
            '52' : 'Steering',
            '53' : 'Exhaust System',
            '54*' : 'Windshield Wipers',
            '55*' : 'Headlights',
            '55' : 'Headlight aim',
            '56*' : 'Taillights',
            '57*' : 'Horn',
            '58' : 'Drivers Seat',
            '59' : 'Suspension / Shocks',
            '60*' : 'Bumpers',
            '61*' : 'Glass',
            '61' : 'TINT',
            '62*' : 'Load Cover',
            '64*' : 'Stop Lights',
            '65*' : 'Tag Light(s)',
            '66*' : 'Dash Lights',
            '67' : 'Wheel Alignment',
            '68*' : 'Rearview Mirrors',
            '69*' : 'Door Latch / Handle',
            '70' : 'Fuel System',
            '70*' : 'Cap',
            '71*' : 'Turn Signals',
            '72' : 'Wheels / Lugs',
            '73*' : 'Hood Catch(s)',
            '74' : 'Floor / Trunk Pan(s)',
            '76*' : 'Fender(s) / Flap(s)',
            '77' : 'Speedometer / Odometer',
            '78*' : 'Hazard Warning Lamp',
            '79*' : 'Park Lamp',
            '80*' : 'Side Marker Lamp',
            '81' : 'Fog / Auxiliary Driving Lamps',
            '82*' : 'Emergency Warning Lamp',
            '83*' : 'Back Up Lamp',
            '84*' : 'Reflectors',
            '85' : 'External Air Brake Component',
            '86*' : 'Low Air Warning Device'
    }
    return switcher.get(charge,"Unknown")

# %%
def MDTaxCode(charge):
    switcher = {
            '9' : 'Title 9 - Fuel Taxes'
    }
    return switcher.get(charge,"Unknown")

# %%
def MDBusiRegu(charge):
    switcher = {
            '10' : 'Title 10 - Motor Fuel and Lubricants'
    }
    return switcher.get(charge,"Unknown")

# %%
def getChargeTitleCat(article, charge):
    _chargeCharter = ''
    if (article=='Transportation Article') | (article=='Maryland Rules'):
        if ("-" in charge):
            chargeBaseCode = charge.split('-')[0]
            _chargeCharter = MDTransCode(chargeBaseCode)
            if _chargeCharter == 'Unknown':
                _chargeCharter = MDTransCode(charge)
        else:
            _chargeCharter = ESERO(chargeBaseCode)
            if _chargeCharter == 'Unknown':
                _chargeCharter = ESERO(charge)            
            
    elif (article=='BR'):
        if ("-" in charge):
            chargeBaseCode = charge.split('-')[0]
            _chargeCharter = MDBusiRegu(chargeBaseCode)
            if _chargeCharter == 'Unknown':
                _chargeCharter = MDBusiRegu(charge)            
            
    elif (article=='TG'):
        if ("-" in charge):
            chargeBaseCode = charge.split('-')[0]
            _chargeCharter = MDTaxCode(chargeBaseCode)
            if _chargeCharter == 'Unknown':
                _chargeCharter = MDTaxCode(charge)            
            
    elif (math.isnan(article)):
        _chargeCharter = ESERO(charge)
            
    return _chargeCharter

# %% [markdown]
# #### Add new empty column to dataset and add value Charge Charter value

# %%
df['Charge Charter'] =""

# %%
for il, row in df.iterrows():
    df.set_value(il,'Charge Charter',getChargeTitleCat(row['Article'],row['Charge']))
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
df.iloc[457371]
# Out:
# SeqID                                   f2bcad2a-116c-4aac-a5b6-c2a7564340d6
# Date Of Stop                                                      05/19/2017
# Time Of Stop                                                        16:17:00
# Agency                                                                   MCP
# SubAgency                                              4th District, Wheaton
# Description                DRIVER USING HANDS TO USE HANDHELD TELEPHONE W...
# Location                                          RUSSELL AVE @ ODEN HAL AVE
# Latitude                                                             39.1523
# Longitude                                                           -77.1988
# Accident                                                                  No
# Belts                                                                     No
# Personal Injury                                                           No
# Property Damage                                                           No
# Fatal                                                                     No
# Commercial License                                                        No
# HAZMAT                                                                    No
# Commercial Vehicle                                                        No
# Alcohol                                                                   No
# Work Zone                                                                 No
# State                                                                     MD
# VehicleType                                                  02 - Automobile
# Year                                                                    2009
# Make                                                                   HONDA
# Model                                                                  CIVIC
# Color                                                                   GRAY
# Violation Type                                                       Warning
# Charge                                                         21-1124.2(d2)
# Article                                               Transportation Article
# Contributed To Accident                                                False
# Race                                                                   ASIAN
# Gender                                                                     M
# Driver City                                                          POTOMAC
# Driver State                                                              MD
# DL State                                                                  MD
# Arrest Type                                                A - Marked Patrol
# Geolocation                            (39.1522533333333, -77.1987583333333)
# Charge Charter                  Title 21 - Vehicle Laws -- Rules of the Road
# Name: 457371, dtype: object

# %% [markdown]
# #### Add additional new columns to assist with analysis

# %%
df['TrafViolYearI'] = pd.to_datetime(df['Date Of Stop']).dt.year

# %%
df['TrafViolMonthI'] = pd.to_datetime(df['Date Of Stop']).dt.month

# %%
df['TrafViolMonthDayI'] = pd.to_datetime(df['Date Of Stop']).dt.day

# %%
df['TrafViolHourI'] = pd.to_datetime(df['Time Of Stop']).dt.hour

# %%
df['TrafViolMonthN'] = pd.to_datetime(df['Date Of Stop']).dt.month_name()

# %%
df['TrafViolWeekdayN'] = pd.to_datetime(df['Date Of Stop']).dt.day_name()

# %%
df['TrafViolHour'] = pd.to_datetime(df['Time Of Stop']).dt.strftime('%I %p')

# %%
df.sample(5)
# Out:
#                                         SeqID Date Of Stop Time Of Stop  \
# 807491   6f8c8742-4bf8-4846-a2f5-898162df17c3   10/12/2015     10:49:00
# 1133722  eb6fbaf9-1821-4e64-8445-a0763f2fde28   05/14/2014     16:26:00
# 193889   1524cc1e-56a5-4d2c-b03f-e6ae6c77f013   08/24/2018     00:39:00
# 1282193  54c20af1-d16f-43ac-9022-1b6cf60251bb   09/05/2013     08:35:00
# 1131130  7da3c7ff-2687-4660-bd3f-c368282b8be7   05/19/2014     11:48:00
#
#         Agency                                        SubAgency  \
# 807491     MCP  6th District, Gaithersburg / Montgomery Village
# 1133722    MCP                      3rd District, Silver Spring
# 193889     MCP                           2nd District, Bethesda
# 1282193    MCP                      3rd District, Silver Spring
# 1131130    MCP                         5th District, Germantown
#
#                                                Description  \
# 807491   DRIVING VEHICLE IN EXCESS OF REASONABLE AND PR...
# 1133722  DRIVER FAILURE TO OBEY DESIGNATED LANE DIRECTIONS
# 193889   FAILURE TO DISPLAY REGISTRATION CARD UPON DEMA...
# 1282193  DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC...
# 1131130  DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGI...
#
#                              Location   Latitude  Longitude Accident  \
# 807491                IS 370 @ IS 270  39.120410 -77.201687       No
# 1133722           NB 29 @ ICC (MD200)  39.078040 -76.952062       No
# 193889       RIVER RD / BRAEBURN PKWY   0.000000   0.000000       No
# 1282193  COLESVILLE RD/ SOUTHWOOD AVE  39.026202 -77.011438       No
# 1131130     RT. 117 @ LIBERTY MILL RD  39.166932 -77.277148       No
#
#             ...              Arrest Type  \
# 807491      ...       R - Unmarked Laser
# 1133722     ...        A - Marked Patrol
# 193889      ...        A - Marked Patrol
# 1282193     ...        A - Marked Patrol
# 1131130     ...        A - Marked Patrol
#
#                                    Geolocation  \
# 807491           (39.12041, -77.2016866666667)
# 1133722          (39.07804, -76.9520616666667)
# 193889                              (0.0, 0.0)
# 1282193  (39.0262016666667, -77.0114383333333)
# 1131130  (39.1669316666667, -77.2771483333333)
#
#                                             Charge Charter TrafViolYearI  \
# 807491        Title 21 - Vehicle Laws -- Rules of the Road          2015
# 1133722       Title 21 - Vehicle Laws -- Rules of the Road          2014
# 193889   Title 13 - Vehicle Laws -- Certificates of  : ...          2018
# 1282193       Title 21 - Vehicle Laws -- Rules of the Road          2013
# 1131130  Title 13 - Vehicle Laws -- Certificates of  : ...          2014
#
#         TrafViolMonthI TrafViolMonthDayI TrafViolHourI TrafViolMonthN  \
# 807491              10                12            10        October
# 1133722              5                14            16            May
# 193889               8                24             0         August
# 1282193              9                 5             8      September
# 1131130              5                19            11            May
#
#         TrafViolWeekdayN TrafViolHour
# 807491            Monday        10 AM
# 1133722        Wednesday        04 PM
# 193889            Friday        12 AM
# 1282193         Thursday        08 AM
# 1131130           Monday        11 AM
#
# [5 rows x 44 columns]

# %%
df['AccidentI'] = np.where(df['Accident'] == 'Yes', 1, 0)

# %%
df['BeltsI'] = np.where(df['Belts'] == 'Yes', 1, 0)

# %%
df['PersonalInjuryI'] = np.where(df['Personal Injury'] == 'Yes', 1, 0)

# %%
df['PropertyDamageI'] = np.where(df['Property Damage'] == 'Yes', 1, 0)

# %%
df['FatalI'] = np.where(df['Fatal'] == 'Yes', 1, 0)

# %%
df['CommercialLicenseI'] = np.where(df['Commercial License'] == 'Yes', 1, 0)

# %%
df['HAZMATI'] = np.where(df['HAZMAT'] == 'Yes', 1, 0)

# %%
df['CommercialVehicleI'] = np.where(df['Commercial Vehicle'] == 'Yes', 1, 0)

# %%
df['AlcoholI'] = np.where(df['Alcohol'] == 'Yes', 1, 0)

# %%
df['WorkZoneI'] = np.where(df['Work Zone'] == 'Yes', 1, 0)

# %%
df.sample(5)
# Out:
#                                         SeqID Date Of Stop Time Of Stop  \
# 492562   bf63b169-79d3-4307-93bb-a350220a11f3   03/14/2017     16:48:00
# 396397   0fe2fe45-e364-4a74-a3a3-2c4473401c80   09/13/2017     00:28:00
# 1217727  07a3c560-2076-4614-ab6c-8bf6fe1c57f3   12/28/2013     12:58:00
# 845332   050658ea-199a-41d6-93a7-ea1e7e25bf26   08/15/2015     08:23:00
# 543898   c07f8719-3864-4bc3-8f42-753c33915189   12/16/2016     23:51:00
#
#         Agency                    SubAgency  \
# 492562     MCP        4th District, Wheaton
# 396397     MCP  3rd District, Silver Spring
# 1217727    MCP      1st District, Rockville
# 845332     MCP        4th District, Wheaton
# 543898     MCP       2nd District, Bethesda
#
#                                                Description  \
# 492562                              DRIVER SPINNING WHEELS
# 396397                           POSSESSING SUSPENDED LIC.
# 1217727                                        Window Tint
# 845332          EXCEEDING THE POSTED SPEED LIMIT OF 30 MPH
# 543898   FAILURE TO DISPLAY REGISTRATION CARD UPON DEMA...
#
#                                  Location   Latitude  Longitude Accident  \
# 492562             2601 UNIVERSITY BLVD W  39.039492 -77.054655       No
# 396397       UNIVERSITY BLVD/E. WAYNE AVE  39.006760 -76.997490       No
# 1217727          HALPINE RD @ CHAPMAN AVE  39.061252 -77.121190       No
# 845332               GEORGIA @ GLENNALLEN  39.061123 -77.052765       No
# 543898   KENILWORTH AVE AT STRATHMORE AVE  38.985805 -77.090462       No
#
#            ...    AccidentI BeltsI PersonalInjuryI PropertyDamageI FatalI  \
# 492562     ...            0      0               0               0      0
# 396397     ...            0      0               0               0      0
# 1217727    ...            0      0               0               0      0
# 845332     ...            0      0               0               0      0
# 543898     ...            0      0               0               0      0
#
#         CommercialLicenseI HAZMATI CommercialVehicleI AlcoholI WorkZoneI
# 492562                   0       0                  0        0         0
# 396397                   0       0                  0        0         0
# 1217727                  0       0                  0        0         0
# 845332                   0       0                  0        0         0
# 543898                   0       0                  0        0         0
#
# [5 rows x 54 columns]

# %%
dfMoCoTrafViol = df[(df['Latitude'] != 0.0) & (df['Longitude'] != 0.0)]

# %%
dfMoCoTrafViol.sample(5)
# Out:
#                                         SeqID Date Of Stop Time Of Stop  \
# 1394151  966137a6-ed95-46b1-b36c-3e520fbd6c20   01/29/2013     21:57:00
# 1339975  18c79cb1-d8b5-4807-be86-91f3464bea3a   05/19/2013     03:04:00
# 211088   faa79ace-ba23-4e23-a7d7-0836d27fc1f2   07/24/2018     22:53:00
# 988165   bb8cd2af-a18b-490f-ad50-dcedafa95aba   01/09/2015     18:52:00
# 971609   93fffe89-c96e-4810-a017-fc5d4bca4fa0   02/04/2015     13:31:00
#
#         Agency                                        SubAgency  \
# 1394151    MCP                      3rd District, Silver Spring
# 1339975    MCP                           2nd District, Bethesda
# 211088     MCP  6th District, Gaithersburg / Montgomery Village
# 988165     MCP                           2nd District, Bethesda
# 971609     MCP                           2nd District, Bethesda
#
#                                                Description  \
# 1394151  FAILURE TO MAINTAIN LEGIBLE REGISTRATION PLATE...
# 1339975  RECKLESS DRIVING VEHICLE IN WANTON AND WILLFUL...
# 211088            DRIVER FAILURE TO STOP AT STOP SIGN LINE
# 988165   DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGI...
# 971609   DRIVING A MOTOR VEHICLE ON HIGHWAY WITHOUT REQ...
#
#                                 Location   Latitude  Longitude Accident  \
# 1394151        STEWART LANE/ LOCKWOOD DR  39.043917 -76.980035       No
# 1339975  NORFOLK AVENUE/ FAIRMONT AVENUE  38.984104 -77.093080       No
# 211088   KENTLANDS BLVD/BEACON SQUARE CT  39.124542 -77.241401       No
# 988165           OLD GEORGETOWN RD X 495  39.015430 -77.118842       No
# 971609             CONNECTICUT AVE/ I495  39.006142 -77.078872       No
#
#            ...    AccidentI BeltsI PersonalInjuryI PropertyDamageI FatalI  \
# 1394151    ...            0      0               0               0      0
# 1339975    ...            0      0               0               0      0
# 211088     ...            0      0               0               0      0
# 988165     ...            0      0               0               0      0
# 971609     ...            0      0               0               0      0
#
#         CommercialLicenseI HAZMATI CommercialVehicleI AlcoholI WorkZoneI
# 1394151                  0       0                  0        0         0
# 1339975                  0       0                  0        0         0
# 211088                   0       0                  0        0         0
# 988165                   0       0                  0        0         0
# 971609                   0       0                  0        0         0
#
# [5 rows x 54 columns]

# %%
dfMoCoTrafViol.to_csv(datadstlocation, index = None, header=True)

# %%
dfMoCoTrafViol.groupby(['SubAgency','Violation Type'])['SeqID'].count().rename("count")
# Out:
# SubAgency                                        Violation Type
# 1st District, Rockville                          Citation           68825
#                                                  ESERO               6366
#                                                  Warning            99200
# 2nd District, Bethesda                           Citation          109179
#                                                  ESERO              11562
#                                                  Warning           111945
# 3rd District, Silver Spring                      Citation          141856
#                                                  ESERO              14133
#                                                  Warning           130303
# 4th District, Wheaton                            Citation          159150
#                                                  ESERO              17075
#                                                  Warning           182853
# 5th District, Germantown                         Citation           67410
#                                                  ESERO               8212
#                                                  Warning            83428
# 6th District, Gaithersburg / Montgomery Village  Citation           70398
#                                                  ESERO              10404
#                                                  Warning           104591
# Headquarters and Special Operations              Citation           24610
#                                                  ESERO               3305
#                                                  Warning            20090
# Name: count, dtype: int64

# %%
dfMoCoTrafViol.groupby(['SubAgency','TrafViolYearI','Violation Type'])['SeqID'].count().rename("count")
# Out:
# SubAgency                                        TrafViolYearI  Violation Type
# 1st District, Rockville                          2012           Citation           8266
#                                                                 ESERO               244
#                                                                 Warning           10792
#                                                  2013           Citation           7403
#                                                                 ESERO               907
#                                                                 Warning           10114
#                                                  2014           Citation          10830
#                                                                 ESERO              1308
#                                                                 Warning           12984
#                                                  2015           Citation          10556
#                                                                 ESERO              1048
#                                                                 Warning           12695
#                                                  2016           Citation           9911
#                                                                 ESERO               936
#                                                                 Warning           13223
#                                                  2017           Citation           8384
#                                                                 ESERO               805
#                                                                 Warning           12921
#                                                  2018           Citation           8985
#                                                                 ESERO               815
#                                                                 Warning           17763
#                                                  2019           Citation           4490
#                                                                 ESERO               303
#                                                                 Warning            8708
# 2nd District, Bethesda                           2012           Citation          15501
#                                                                 ESERO               208
#                                                                 Warning            6178
#                                                  2013           Citation          15623
#                                                                 ESERO              1035
#                                                                 Warning            7105
#                                                                                   ...
# 6th District, Gaithersburg / Montgomery Village  2018           Citation           6691
#                                                                 ESERO              1024
#                                                                 Warning           15228
#                                                  2019           Citation           3783
#                                                                 ESERO               541
#                                                                 Warning            8620
# Headquarters and Special Operations              2012           Citation            962
#                                                                 ESERO                35
#                                                                 Warning            1104
#                                                  2013           Citation           3130
#                                                                 ESERO               548
#                                                                 Warning            2220
#                                                  2014           Citation           3568
#                                                                 ESERO               814
#                                                                 Warning            2812
#                                                  2015           Citation           4346
#                                                                 ESERO               752
#                                                                 Warning            3207
#                                                  2016           Citation           4611
#                                                                 ESERO               630
#                                                                 Warning            3461
#                                                  2017           Citation           2058
#                                                                 ESERO               216
#                                                                 Warning            2201
#                                                  2018           Citation           3596
#                                                                 ESERO               219
#                                                                 Warning            3220
#                                                  2019           Citation           2339
#                                                                 ESERO                91
#                                                                 Warning            1865
# Name: count, Length: 168, dtype: int64

# %%
dfMoCoTrafViol.groupby(['SubAgency','TrafViolMonthN','Violation Type'])['SeqID'].count().rename("count")
# Out:
# SubAgency                            TrafViolMonthN  Violation Type
# 1st District, Rockville              April           Citation          6784
#                                                      ESERO              670
#                                                      Warning           9856
#                                      August          Citation          5344
#                                                      ESERO              571
#                                                      Warning           8171
#                                      December        Citation          4436
#                                                      ESERO              448
#                                                      Warning           6652
#                                      February        Citation          5488
#                                                      ESERO              503
#                                                      Warning           8115
#                                      January         Citation          5371
#                                                      ESERO              512
#                                                      Warning           7909
#                                      July            Citation          5966
#                                                      ESERO              527
#                                                      Warning           8466
#                                      June            Citation          6111
#                                                      ESERO              551
#                                                      Warning           9191
#                                      March           Citation          6184
#                                                      ESERO              702
#                                                      Warning           9299
#                                      May             Citation          6607
#                                                      ESERO              592
#                                                      Warning           9079
#                                      November        Citation          5039
#                                                      ESERO              389
#                                                      Warning           6705
#                                                                        ...
# Headquarters and Special Operations  December        Citation          2266
#                                                      ESERO              209
#                                                      Warning           1607
#                                      February        Citation          1503
#                                                      ESERO              156
#                                                      Warning           1232
#                                      January         Citation          1332
#                                                      ESERO              173
#                                                      Warning           1189
#                                      July            Citation          2423
#                                                      ESERO              396
#                                                      Warning           1999
#                                      June            Citation          2267
#                                                      ESERO              287
#                                                      Warning           1726
#                                      March           Citation          1630
#                                                      ESERO              368
#                                                      Warning           1593
#                                      May             Citation          2470
#                                                      ESERO              306
#                                                      Warning           1881
#                                      November        Citation          2163
#                                                      ESERO              297
#                                                      Warning           1890
#                                      October         Citation          1770
#                                                      ESERO              237
#                                                      Warning           1680
#                                      September       Citation          2231
#                                                      ESERO              244
#                                                      Warning           1731
# Name: count, Length: 252, dtype: int64

# %%
dfMoCoTrafViol.groupby(['SubAgency','TrafViolWeekdayN','Violation Type'])['SeqID'].count().rename("count")
# Out:
# SubAgency                                        TrafViolWeekdayN  Violation Type
# 1st District, Rockville                          Friday            Citation          10500
#                                                                    ESERO               908
#                                                                    Warning           13475
#                                                  Monday            Citation           9030
#                                                                    ESERO               824
#                                                                    Warning           12700
#                                                  Saturday          Citation           6191
#                                                                    ESERO               647
#                                                                    Warning           10422
#                                                  Sunday            Citation           6015
#                                                                    ESERO               522
#                                                                    Warning            9641
#                                                  Thursday          Citation          11690
#                                                                    ESERO               967
#                                                                    Warning           15592
#                                                  Tuesday           Citation          13167
#                                                                    ESERO              1326
#                                                                    Warning           20206
#                                                  Wednesday         Citation          12232
#                                                                    ESERO              1172
#                                                                    Warning           17164
# 2nd District, Bethesda                           Friday            Citation          16660
#                                                                    ESERO              1680
#                                                                    Warning           15922
#                                                  Monday            Citation          14688
#                                                                    ESERO              1579
#                                                                    Warning           16084
#                                                  Saturday          Citation           9672
#                                                                    ESERO              1207
#                                                                    Warning            9270
#                                                                                      ...
# 6th District, Gaithersburg / Montgomery Village  Thursday          Citation          11033
#                                                                    ESERO              1663
#                                                                    Warning           17529
#                                                  Tuesday           Citation          11606
#                                                                    ESERO              1903
#                                                                    Warning           18533
#                                                  Wednesday         Citation          12124
#                                                                    ESERO              1734
#                                                                    Warning           17851
# Headquarters and Special Operations              Friday            Citation           4627
#                                                                    ESERO               545
#                                                                    Warning            3351
#                                                  Monday            Citation           1759
#                                                                    ESERO               506
#                                                                    Warning            2056
#                                                  Saturday          Citation           4966
#                                                                    ESERO               369
#                                                                    Warning            2403
#                                                  Sunday            Citation           2913
#                                                                    ESERO               159
#                                                                    Warning            1285
#                                                  Thursday          Citation           4379
#                                                                    ESERO               638
#                                                                    Warning            4206
#                                                  Tuesday           Citation           2500
#                                                                    ESERO               447
#                                                                    Warning            3169
#                                                  Wednesday         Citation           3466
#                                                                    ESERO               641
#                                                                    Warning            3620
# Name: count, Length: 147, dtype: int64

# %%
dfMoCoTrafViol.groupby(['SubAgency','TrafViolHour','Violation Type'])['SeqID'].count().rename("count")
# Out:
# SubAgency                            TrafViolHour  Violation Type
# 1st District, Rockville              01 AM         Citation          3296
#                                                    ESERO              155
#                                                    Warning           4607
#                                      01 PM         Citation          2883
#                                                    ESERO              227
#                                                    Warning           4141
#                                      02 AM         Citation          2952
#                                                    ESERO               91
#                                                    Warning           2457
#                                      02 PM         Citation          3267
#                                                    ESERO              255
#                                                    Warning           3966
#                                      03 AM         Citation          1739
#                                                    ESERO               45
#                                                    Warning           1036
#                                      03 PM         Citation          3158
#                                                    ESERO              196
#                                                    Warning           3431
#                                      04 AM         Citation           953
#                                                    ESERO               21
#                                                    Warning            606
#                                      04 PM         Citation          4144
#                                                    ESERO              291
#                                                    Warning           4942
#                                      05 AM         Citation           455
#                                                    ESERO               13
#                                                    Warning            397
#                                      05 PM         Citation          3858
#                                                    ESERO              329
#                                                    Warning           5079
#                                                                      ...
# Headquarters and Special Operations  08 AM         Citation           350
#                                                    ESERO              125
#                                                    Warning            560
#                                      08 PM         Citation           906
#                                                    ESERO              149
#                                                    Warning            920
#                                      09 AM         Citation           422
#                                                    ESERO              181
#                                                    Warning            537
#                                      09 PM         Citation          1199
#                                                    ESERO              207
#                                                    Warning           1257
#                                      10 AM         Citation           496
#                                                    ESERO              149
#                                                    Warning            764
#                                      10 PM         Citation          1755
#                                                    ESERO              287
#                                                    Warning           1669
#                                      11 AM         Citation           640
#                                                    ESERO              184
#                                                    Warning            839
#                                      11 PM         Citation          2261
#                                                    ESERO              350
#                                                    Warning           2091
#                                      12 AM         Citation          2506
#                                                    ESERO              243
#                                                    Warning           1685
#                                      12 PM         Citation           746
#                                                    ESERO              180
#                                                    Warning            864
# Name: count, Length: 504, dtype: int64

# %%
dfMoCoTrafViol.groupby(['SubAgency','Gender','Violation Type'])['SeqID'].count().rename("count")
# Out:
# SubAgency                                        Gender  Violation Type
# 1st District, Rockville                          F       Citation           22773
#                                                          ESERO               2086
#                                                          Warning            37548
#                                                  M       Citation           46031
#                                                          ESERO               4280
#                                                          Warning            61514
#                                                  U       Citation              21
#                                                          Warning              138
# 2nd District, Bethesda                           F       Citation           37831
#                                                          ESERO               3877
#                                                          Warning            45367
#                                                  M       Citation           71336
#                                                          ESERO               7685
#                                                          Warning            66385
#                                                  U       Citation              12
#                                                          Warning              193
# 3rd District, Silver Spring                      F       Citation           38959
#                                                          ESERO               4452
#                                                          Warning            44280
#                                                  M       Citation          102779
#                                                          ESERO               9679
#                                                          Warning            85199
#                                                  U       Citation             118
#                                                          ESERO                  2
#                                                          Warning              824
# 4th District, Wheaton                            F       Citation           40504
#                                                          ESERO               4710
#                                                          Warning            62270
#                                                  M       Citation          118609
#                                                          ESERO              12365
#                                                          Warning           120465
#                                                  U       Citation              37
#                                                          Warning              118
# 5th District, Germantown                         F       Citation           21183
#                                                          ESERO               2652
#                                                          Warning            33008
#                                                  M       Citation           46206
#                                                          ESERO               5560
#                                                          Warning            50382
#                                                  U       Citation              21
#                                                          Warning               38
# 6th District, Gaithersburg / Montgomery Village  F       Citation           21671
#                                                          ESERO               3510
#                                                          Warning            38615
#                                                  M       Citation           48700
#                                                          ESERO               6892
#                                                          Warning            65673
#                                                  U       Citation              27
#                                                          ESERO                  2
#                                                          Warning              303
# Headquarters and Special Operations              F       Citation            5942
#                                                          ESERO                608
#                                                          Warning             5556
#                                                  M       Citation           18652
#                                                          ESERO               2696
#                                                          Warning            14516
#                                                  U       Citation              16
#                                                          ESERO                  1
#                                                          Warning               18
# Name: count, dtype: int64

# %% [markdown]
# #### Visualization dashboard and findings
# https://public.tableau.com/profile/piyushpathak#!/vizhome/MoCoTrafViol/MCP
